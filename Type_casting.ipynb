# %% [markdown]
# # """ Other Data types to INT type conversion"""

# %%
print(int(3.14))
# Out:
# 3

# %%
print(int(230.0,110.23))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(int(230.0,110.23))
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(1+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 int(1+3j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
print(int('ten'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(int('ten'))
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # """Other Data types to FLOAT type conversion"""

# %%
print(float(10))
# Out:
# 10.0

# %%
print(float(1+3j))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(float(1+3j))
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('1+2j')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 float('1+2j')
#
# ValueError: could not convert string to float: '1+2j'

# %%
print(float(True))
# Out:
# 1.0

# %%
float('20')
# Out:
# 20.0

# %% [markdown]
# # """ Other data types to complex type conversion """

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex()
# Out:
# 0j

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(True,True)
# Out:
# (1+1j)

# %%
complex('20')
# Out:
# (20+0j)

# %%
complex('20','10')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 complex('20','10')
#
# TypeError: complex() argument 'real' must be a real number, not str

# %% [markdown]
# # """ Other data types to string type conversion """

# %%
str(10)
# Out:
# '10'

# %%
str(1.2)
# Out:
# '1.2'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+3j)
# Out:
# '(1+3j)'

# %%
str('str')
# Out:
# 'str'

# %%
int(10)
# Out:
# 10

# %%
float(11.2)
# Out:
# 11.2

# %%
bool(False)
# Out:
# False

# %%
isinstance(10,int)  # isinstance() is used for checking the type of the variable
# Out:
# True
