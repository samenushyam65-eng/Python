# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'

# %%
int(0x19)
# Out:
# 25

# %% [markdown]
# # """" BITWISE OPERATOR"""

# %%
print(~11) # add 1 to the number and change the sign
# Out:
# -12

# %% [markdown]
# # AND (&)

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(13)
# Out:
# '0b1101'

# %%
12&13
# Out:
# 12

# %% [markdown]
# # OR (|)

# %%
13|12
# Out:
# 13

# %% [markdown]
# # X-OR (^)

# %%
12^13
# Out:
# 1

# %% [markdown]
# # LEFT SHIFT (<<)

# %%
12<<1
# Out:
# 24

# %% [markdown]
# # RIGHT SHIFT (>>)

# %%
12>>1
# Out:
# 6
