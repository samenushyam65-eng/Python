# %%
# x = sqrt(25)

# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(25))
# Out:
# 5

# %%
math.floor(3.23)
# Out:
# 3

# %%
math.ceil(3.23)
# Out:
# 4

# %%
math.pow(3,2)
# Out:
# 9.0

# %%
import math as m
print(m.pow(3,2))
print(m.floor(3.23))
print(m.ceil(3.23))
# Out:
# 9.0
# 3
# 4

# %%
from math import sqrt,floor,ceil,pow
print(sqrt(25))
print(floor(3.23))  
print(ceil(3.23))
print(pow(3,2))
# Out:
# 5.0
# 3
# 4
# 9.0

# %%
from math import *
print(sqrt(25)) 
print(floor(3.23))
print(ceil(3.23))
print(pow(3,2))
# Out:
# 5.0
# 3
# 4
# 9.0

# %%
x = input("Enter your name: ")
print("Hello,", x)
# Out:
# Hello, Shyam

# %%
x=input()[0]
x
# Out:
# 's'

# %%
x=input()[3:4]
x
# Out:
# 'a'

# %%
x=int(input())
y=int(input())
print(x,y)
print(x+y)
# Out:
# 2 3
# 5

# %%
x=eval(input("Enter your expression: "))
x
# Out:
# 3148
