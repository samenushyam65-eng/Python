# %%
t= ()

# %%
t1=(10,20,30,40,50,50)
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t2 = (10,'shyam',1+2j,True)
t2
# Out:
# (10, 'shyam', (1+2j), True)

# %%
print(t1)
print(t2)
# Out:
# (10, 20, 30, 40, 50, 50)
# (10, 'shyam', (1+2j), True)

# %%
type(t1)
# Out:
# tuple

# %%
t1.count(50)
# Out:
# 2

# %%
t1.index(50)
# Out:
# 4

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t1[0]
# Out:
# 10

# %%
t1[:]
# Out:
# (10, 20, 30, 40, 50, 50)

# %%
t1[0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t1[0]=1
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1*3
# Out:
# (10, 20, 30, 40, 50, 50, 10, 20, 30, 40, 50, 50, 10, 20, 30, 40, 50, 50)

# %%
tuple1 = (10,20,30)
tuple2 = (40,50,60)

# %%
print(type(tuple1))
print(type(tuple2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
print(tuple1 + tuple2) # it will concatenate two tuples
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
10 in tuple1
# Out:
# True

# %%
if 10 in tuple1:
    print("10 is present in tuple1")
# Out:
# 10 is present in tuple1

# %%
for i in tuple1:
    print(i)
# Out:
# 10
# 20
# 30

# %%
for i in enumerate(tuple1):
    print(i)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)

# %%
tup=(2,8,9,3,4,6,1,8,6,2,7,6)

# %%
sorted(tup)
# Out:
# [1, 2, 2, 3, 4, 6, 6, 6, 7, 8, 8, 9]

# %%
sorted(tup,reverse=True)
# Out:
# [9, 8, 8, 7, 6, 6, 6, 4, 3, 2, 2, 1]
