# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\Power bi internship\internship\Week 1\19-02-2026\19-02-2026 (2018).csv")

# %%
df.head()
# Out:
#    slno  orderid   orderDate deliveryDate Mr./Mrs./Miss name   value
# 0     1    10001  01-01-2018   09-01-2018            mr    a  Rs.100
# 1     2    10002  02-01-2018   10-01-2018           mrs    b  Rs.200
# 2     3    10003  03-01-2018   11-01-2018            mr    c  Rs.300
# 3     4    10004  04-01-2018   12-01-2018           mrs    d  Rs.400
# 4     5    10005  05-01-2018   13-01-2018            mr    e  Rs.500

# %%
orderid = ["10001","10002","10003","10004","10005","10006","10007","10008","10009"]

plt.plot(df['orderid'],df['value'],"o--r")

plt.xticks(df['orderid'], orderid,rotation=75)
plt.show()

# %%
df
# Out:
#    slno  orderid   orderDate deliveryDate Mr./Mrs./Miss name   value
# 0     1    10001  01-01-2018   09-01-2018            mr    a  Rs.100
# 1     2    10002  02-01-2018   10-01-2018           mrs    b  Rs.200
# 2     3    10003  03-01-2018   11-01-2018            mr    c  Rs.300
# 3     4    10004  04-01-2018   12-01-2018           mrs    d  Rs.400
# 4     5    10005  05-01-2018   13-01-2018            mr    e  Rs.500
# 5     6    10006  06-01-2018   14-01-2018           mrs    f  Rs.600
# 6     7    10007  07-01-2018   15-01-2018            mr    g  Rs.700
# 7     8    10008  08-01-2018   16-01-2018           mrs    h  Rs.800
# 8     9    10009  09-01-2018   17-01-2018            mr    i  Rs.900

# %%
df
# Out:
#    slno  orderid   orderDate deliveryDate Mr./Mrs./Miss name   value
# 0     1    10001  01-01-2018   09-01-2018            mr    a  Rs.100
# 1     2    10002  02-01-2018   10-01-2018           mrs    b  Rs.200
# 2     3    10003  03-01-2018   11-01-2018            mr    c  Rs.300
# 3     4    10004  04-01-2018   12-01-2018           mrs    d  Rs.400
# 4     5    10005  05-01-2018   13-01-2018            mr    e  Rs.500
# 5     6    10006  06-01-2018   14-01-2018           mrs    f  Rs.600
# 6     7    10007  07-01-2018   15-01-2018            mr    g  Rs.700
# 7     8    10008  08-01-2018   16-01-2018           mrs    h  Rs.800
# 8     9    10009  09-01-2018   17-01-2018            mr    i  Rs.900
